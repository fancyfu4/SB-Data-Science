# %% [markdown]
# # Imports

# %%
# General
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from numpy import array

from sklearn import linear_model
from sklearn import metrics
from sklearn.feature_selection import RFE
from sklearn.metrics import mean_squared_error, confusion_matrix, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

#Models 
from sklearn.ensemble               import RandomForestRegressor
from sklearn.linear_model           import LinearRegression
from sklearn.tree                   import DecisionTreeRegressor
from sklearn.neighbors              import KNeighborsRegressor

# %% [markdown]
# # Load Data

# %%
#Load file from EDA 
health_data = pd.read_csv('../data/health_data.csv')

# %%
#Check data
health_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2908 entries, 0 to 2907
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   State                      2908 non-null   object
#  1   County                     2908 non-null   object
#  2   Life Expectancy            2908 non-null   float64
#  3   Population                 2908 non-null   int64
#  4   % Rural                    2908 non-null   int64
#  5   Premature Deaths           2908 non-null   float64
#  6   % Smoking                  2908 non-null   int64
#  7   % Obesity                  2908 non-null   int64
#  8   % Physical Inactivy        2908 non-null   int64
#  9   % Excessive Drinking       2908 non-null   int64
#  10  % Uninsured                2908 non-null   float64
#  11  PCP Number                 2908 non-null   float64
#  12  PCP Rate                   2908 non-null   float64
#  13  MHP Number                 2908 non-null   float64
#  14  MHP Rate                   2908 non-null   float64
#  15  Preventable Hospital Rate  2908 non-null   float64
#  16  % Mammogram                2908 non-null   float64
#  17  % Flu Vaccine              2908 non-null   float64
#  18  % Unemployed               2908 non-null   object
#  19  Median Household Income    2908 non-null   int64
# dtypes: float64(10), int64(7), object(3)
# memory usage: 454.5+ KB

# %%
#Edit '% Unemployed' to be float type
health_data['% Unemployed']=health_data['% Unemployed'].str.replace(',', '.').astype(float)

# %%
health_data.head()
# Out:
#      State   County  Life Expectancy  Population  % Rural  Premature Deaths  \
# 0  Alabama  Autauga        77.162581       55869    22921             787.0
# 1  Alabama  Baldwin        78.213405      223234    77060            3147.0
# 2  Alabama  Barbour        74.054741       24686    18613             515.0
# 3  Alabama     Bibb        73.408784       22394    15663             476.0
# 4  Alabama   Blount        74.370874       57826    51562            1100.0
#
#    % Smoking  % Obesity  % Physical Inactivy  % Excessive Drinking  \
# 0         20         33                   31                    14
# 1         19         30                   25                    19
# 2         26         41                   28                    12
# 3         23         37                   33                    15
# 4         23         33                   33                    16
#
#    % Uninsured  PCP Number  PCP Rate  MHP Number  MHP Rate  \
# 0         10.0        26.0      47.0        16.0      29.0
# 1         13.0       153.0      70.0       220.0      99.0
# 2         14.0         8.0      32.0         3.0      12.0
# 3         11.0        12.0      54.0         6.0      27.0
# 4         14.0        12.0      21.0        10.0      17.0
#
#    Preventable Hospital Rate  % Mammogram  % Flu Vaccine  % Unemployed  \
# 0                     6650.0         39.0           42.0           2.7
# 1                     3471.0         43.0           46.0           2.7
# 2                     5314.0         44.0           39.0           3.8
# 3                     6690.0         33.0           40.0           3.1
# 4                     4440.0         37.0           40.0           2.7
#
#    Median Household Income
# 0                    58233
# 1                    59871
# 2                    35972
# 3                    47918
# 4                    52902

# %%
health_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2908 entries, 0 to 2907
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   State                      2908 non-null   object
#  1   County                     2908 non-null   object
#  2   Life Expectancy            2908 non-null   float64
#  3   Population                 2908 non-null   int64
#  4   % Rural                    2908 non-null   int64
#  5   Premature Deaths           2908 non-null   float64
#  6   % Smoking                  2908 non-null   int64
#  7   % Obesity                  2908 non-null   int64
#  8   % Physical Inactivy        2908 non-null   int64
#  9   % Excessive Drinking       2908 non-null   int64
#  10  % Uninsured                2908 non-null   float64
#  11  PCP Number                 2908 non-null   float64
#  12  PCP Rate                   2908 non-null   float64
#  13  MHP Number                 2908 non-null   float64
#  14  MHP Rate                   2908 non-null   float64
#  15  Preventable Hospital Rate  2908 non-null   float64
#  16  % Mammogram                2908 non-null   float64
#  17  % Flu Vaccine              2908 non-null   float64
#  18  % Unemployed               2908 non-null   float64
#  19  Median Household Income    2908 non-null   int64
# dtypes: float64(11), int64(7), object(2)
# memory usage: 454.5+ KB

# %% [markdown]
# # Explore The Data

# %%
corr=health_data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_bbc19_row0_col0, #T_bbc19_row1_col1, #T_bbc19_row2_col2, #T_bbc19_row3_col3, #T_bbc19_row4_col4, #T_bbc19_row5_col5, #T_bbc19_row6_col6, #T_bbc19_row7_col7, #T_bbc19_row8_col8, #T_bbc19_row9_col9, #T_bbc19_row10_col10, #T_bbc19_row11_col11, #T_bbc19_row12_col12, #T_bbc19_row13_col13, #T_bbc19_row14_col14, #T_bbc19_row15_col15, #T_bbc19_row16_col16, #T_bbc19_row17_col17 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_bbc19_row0_col1 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_bbc19_row0_col2, #T_bbc19_row12_col5, #T_bbc19_row16_col3, #T_bbc19_row16_col17 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_bbc19_row0_col3, #T_bbc19_row1_col15, #T_bbc19_row9_col7, #T_bbc19_row9_col14 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_bbc19_row0_col4 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_bbc19_row0_col5, #T_bbc19_row0_col6, #T_bbc19_row0_col13, #T_bbc19_row4_col0, #T_bbc19_row4_col1, #T_bbc19_row4_col3, #T_bbc19_row4_col9, #T_bbc19_row4_col10, #T_bbc19_row4_col11, #T_bbc19_row4_col17, #T_bbc19_row6_col7, #T_bbc19_row6_col12, #T_bbc19_row8_col2, #T_bbc19_row8_col14, #T_bbc19_row8_col15, #T_bbc19_row14_col8, #T_bbc19_row16_col15, #T_bbc19_row17_col4, #T_bbc19_row17_col16 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_bbc19_row0_col7 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_bbc19_row0_col8 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_bbc19_row0_col9, #T_bbc19_row0_col15, #T_bbc19_row10_col11, #T_bbc19_row13_col8 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_bbc19_row0_col10, #T_bbc19_row10_col14, #T_bbc19_row12_col0 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_bbc19_row0_col11 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_bbc19_row0_col12, #T_bbc19_row8_col16 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_bbc19_row0_col14, #T_bbc19_row15_col0 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_bbc19_row0_col16, #T_bbc19_row4_col2, #T_bbc19_row4_col12 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_bbc19_row0_col17, #T_bbc19_row17_col0 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_bbc19_row1_col0, #T_bbc19_row10_col12 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_bbc19_row1_col2 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_bbc19_row1_col3, #T_bbc19_row3_col1 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_bbc19_row1_col4, #T_bbc19_row1_col6, #T_bbc19_row7_col1, #T_bbc19_row7_col12, #T_bbc19_row14_col11 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_bbc19_row1_col5, #T_bbc19_row8_col1, #T_bbc19_row10_col13, #T_bbc19_row13_col9, #T_bbc19_row16_col1 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_bbc19_row1_col7, #T_bbc19_row1_col14, #T_bbc19_row2_col6, #T_bbc19_row3_col7, #T_bbc19_row11_col15, #T_bbc19_row15_col3, #T_bbc19_row15_col11 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_bbc19_row1_col8, #T_bbc19_row14_col9 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_bbc19_row1_col9, #T_bbc19_row9_col1 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_bbc19_row1_col10, #T_bbc19_row2_col14, #T_bbc19_row8_col13 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_bbc19_row1_col11, #T_bbc19_row11_col1 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_bbc19_row1_col12, #T_bbc19_row12_col7 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_bbc19_row1_col13, #T_bbc19_row3_col8, #T_bbc19_row8_col0 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_bbc19_row1_col16, #T_bbc19_row11_col16, #T_bbc19_row15_col5 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_bbc19_row1_col17, #T_bbc19_row14_col17 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_bbc19_row2_col0 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_bbc19_row2_col1 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_bbc19_row2_col3 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_bbc19_row2_col4, #T_bbc19_row8_col5 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_bbc19_row2_col5, #T_bbc19_row3_col15, #T_bbc19_row7_col15, #T_bbc19_row12_col16 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_bbc19_row2_col7, #T_bbc19_row2_col13, #T_bbc19_row17_col2 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_bbc19_row2_col8, #T_bbc19_row10_col2 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_bbc19_row2_col9, #T_bbc19_row4_col8 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_bbc19_row2_col10, #T_bbc19_row3_col12, #T_bbc19_row5_col8, #T_bbc19_row11_col7, #T_bbc19_row12_col3, #T_bbc19_row15_col1 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_bbc19_row2_col11, #T_bbc19_row3_col2, #T_bbc19_row10_col3 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_bbc19_row2_col12 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_bbc19_row2_col15, #T_bbc19_row9_col10 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_bbc19_row2_col16, #T_bbc19_row16_col8 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_bbc19_row2_col17 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_bbc19_row3_col0, #T_bbc19_row12_col17 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_bbc19_row3_col4, #T_bbc19_row3_col6, #T_bbc19_row3_col16, #T_bbc19_row7_col11, #T_bbc19_row15_col4 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_bbc19_row3_col5, #T_bbc19_row16_col0 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_bbc19_row3_col9 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_bbc19_row3_col10 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_bbc19_row3_col11 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_bbc19_row3_col13, #T_bbc19_row11_col2, #T_bbc19_row12_col4, #T_bbc19_row12_col15, #T_bbc19_row14_col5 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_bbc19_row3_col14 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_bbc19_row3_col17, #T_bbc19_row13_col5, #T_bbc19_row16_col6 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_bbc19_row4_col5 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_bbc19_row4_col6 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_bbc19_row4_col7, #T_bbc19_row4_col15, #T_bbc19_row6_col10 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_bbc19_row4_col13 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_bbc19_row4_col14, #T_bbc19_row8_col11 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_bbc19_row4_col16, #T_bbc19_row6_col13, #T_bbc19_row15_col14 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_bbc19_row5_col0, #T_bbc19_row13_col10 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_bbc19_row5_col1, #T_bbc19_row5_col10, #T_bbc19_row6_col3, #T_bbc19_row6_col15 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_bbc19_row5_col2 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_bbc19_row5_col3, #T_bbc19_row8_col12 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_bbc19_row5_col4 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_bbc19_row5_col6, #T_bbc19_row7_col0 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_bbc19_row5_col7, #T_bbc19_row15_col16 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_bbc19_row5_col9, #T_bbc19_row6_col9 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_bbc19_row5_col11, #T_bbc19_row6_col11 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_bbc19_row5_col12 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_bbc19_row5_col13, #T_bbc19_row9_col0 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_bbc19_row5_col14, #T_bbc19_row7_col9, #T_bbc19_row14_col4 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_bbc19_row5_col15, #T_bbc19_row13_col0, #T_bbc19_row16_col14 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_bbc19_row5_col16, #T_bbc19_row6_col16 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_bbc19_row5_col17, #T_bbc19_row8_col3, #T_bbc19_row8_col9 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_bbc19_row6_col0, #T_bbc19_row6_col1, #T_bbc19_row13_col7 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_bbc19_row6_col2, #T_bb

# %% [markdown]
# Based off of the correlation heatmap, the following insights can be seen:
# - Life expectancy most highly correlated with median household income (0.635) and % excessive drinking (0.554)
# - Life expectancy is negatively related with % Smoking (-0.7)
#
# Other interesting highest correlations were found to be between
# - % physical inactivity and % smoking (0.653)
# - PCP number and population (0.964)
# - MHP number and population (0.902)
# - PCP number and premature deaths(0.93)
# - MHP number and premature deaths(0.859)
# - Population and premature deaths (0.97)
# - PCP number and MHP number (0.93)

# %%
data = health_data.drop(["State", "County"], axis=1)

# %%
data.head()
# Out:
#    Life Expectancy  Population  % Rural  Premature Deaths  % Smoking  \
# 0        77.162581       55869    22921             787.0         20
# 1        78.213405      223234    77060            3147.0         19
# 2        74.054741       24686    18613             515.0         26
# 3        73.408784       22394    15663             476.0         23
# 4        74.370874       57826    51562            1100.0         23
#
#    % Obesity  % Physical Inactivy  % Excessive Drinking  % Uninsured  \
# 0         33                   31                    14         10.0
# 1         30                   25                    19         13.0
# 2         41                   28                    12         14.0
# 3         37                   33                    15         11.0
# 4         33                   33                    16         14.0
#
#    PCP Number  PCP Rate  MHP Number  MHP Rate  Preventable Hospital Rate  \
# 0        26.0      47.0        16.0      29.0                     6650.0
# 1       153.0      70.0       220.0      99.0                     3471.0
# 2         8.0      32.0         3.0      12.0                     5314.0
# 3        12.0      54.0         6.0      27.0                     6690.0
# 4        12.0      21.0        10.0      17.0                     4440.0
#
#    % Mammogram  % Flu Vaccine  % Unemployed  Median Household Income
# 0         39.0           42.0           2.7                    58233
# 1         43.0           46.0           2.7                    59871
# 2         44.0           39.0           3.8                    35972
# 3         33.0           40.0           3.1                    47918
# 4         37.0           40.0           2.7                    52902

# %%
data.columns
# Out:
# Index(['Life Expectancy', 'Population', '% Rural', 'Premature Deaths',
#        '% Smoking', '% Obesity', '% Physical Inactivy', '% Excessive Drinking',
#        '% Uninsured', 'PCP Number', 'PCP Rate', 'MHP Number', 'MHP Rate',
#        'Preventable Hospital Rate', '% Mammogram', '% Flu Vaccine',
#        '% Unemployed', 'Median Household Income'],
#       dtype='object')

# %%
health_data.head()
# Out:
#      State   County  Life Expectancy  Population  % Rural  Premature Deaths  \
# 0  Alabama  Autauga        77.162581       55869    22921             787.0
# 1  Alabama  Baldwin        78.213405      223234    77060            3147.0
# 2  Alabama  Barbour        74.054741       24686    18613             515.0
# 3  Alabama     Bibb        73.408784       22394    15663             476.0
# 4  Alabama   Blount        74.370874       57826    51562            1100.0
#
#    % Smoking  % Obesity  % Physical Inactivy  % Excessive Drinking  \
# 0         20         33                   31                    14
# 1         19         30                   25                    19
# 2         26         41                   28                    12
# 3         23         37                   33                    15
# 4         23         33                   33                    16
#
#    % Uninsured  PCP Number  PCP Rate  MHP Number  MHP Rate  \
# 0         10.0        26.0      47.0        16.0      29.0
# 1         13.0       153.0      70.0       220.0      99.0
# 2         14.0         8.0      32.0         3.0      12.0
# 3         11.0        12.0      54.0         6.0      27.0
# 4         14.0        12.0      21.0        10.0      17.0
#
#    Preventable Hospital Rate  % Mammogram  % Flu Vaccine  % Unemployed  \
# 0                     6650.0         39.0           42.0           2.7
# 1                     3471.0         43.0           46.0           2.7
# 2                     5314.0         44.0           39.0           3.8
# 3                     6690.0         33.0           40.0           3.1
# 4                     4440.0         37.0           40.0           2.7
#
#    Median Household Income
# 0                    58233
# 1                    59871
# 2                    35972
# 3                    47918
# 4                    52902

# %% [markdown]
# # RFE feature selection

# %%
y = data['Life Expectancy']
X = data.drop(columns=['Life Expectancy'],axis=1)

print("Feature data dimension: ", X.shape)
# Out:
# Feature data dimension:  (2908, 17)

# %%
estimator = RandomForestRegressor(random_state=1, n_estimators=100)
selector = RFE(estimator, n_features_to_select=10, step=1)
selector = selector.fit(X, y)

# %%
selector.support_
# Out:
# array([ True,  True,  True,  True,  True,  True,  True, False, False,
#        False, False, False,  True,  True, False, False,  True])

# %%
selector.n_features_
# Out:
# 10

# %%
selector.ranking_
# Out:
# array([1, 1, 1, 1, 1, 1, 1, 4, 7, 2, 8, 5, 1, 1, 6, 3, 1])

# %%
f = selector.get_support(1)
top=data[data.columns[f]]
top
# Out:
#       Life Expectancy  Population  % Rural  Premature Deaths  % Smoking  \
# 0           77.162581       55869    22921             787.0         20
# 1           78.213405      223234    77060            3147.0         19
# 2           74.054741       24686    18613             515.0         26
# 3           73.408784       22394    15663             476.0         23
# 4           74.370874       57826    51562            1100.0         23
# ...               ...         ...      ...               ...        ...
# 2903        77.533795       42343     4782             527.0         19
# 2904        87.471434       23464     9887             109.0         13
# 2905        78.244365       20226     9101             271.0         21
# 2906        79.825612        7805     3068             104.0         19
# 2907        81.965286        6927     3931              76.0         21
#
#       % Obesity  % Physical Inactivy  MHP Rate  Preventable Hospital Rate  \
# 0            33                   31      29.0                     6650.0
# 1            30                   25      99.0                     3471.0
# 2            41                   28      12.0                     5314.0
# 3            37                   33      27.0                     6690.0
# 4            33                   33      17.0                     4440.0
# ...         ...                  ...       ...                        ...
# 2903         30                   24     250.0                     2543.0
# 2904         11                   11     494.0                     3181.0
# 2905         35                   25     356.0                     2839.0
# 2906         29                   29     397.0                     3957.0
# 2907         37                   26     188.0                     2662.0
#
#       % Unemployed
# 0              2.7
# 1              2.7
# 2              3.8
# 3              3.1
# 4              2.7
# ...            ...
# 2903           3.9
# 2904           2.7
# 2905           3.9
# 2906           3.9
# 2907           2.9
#
# [2908 rows x 10 columns]

# %% [markdown]
# # Random Forest Regressor

# %%
y = top['Life Expectancy']
X = top.drop(columns=['Life Expectancy'],axis=1)

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=123)

# %%
rfr = RandomForestRegressor()
model = rfr.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
#Evaluate the model.
rfr_score = rfr.score(X_train, y_train)
rfr_score_test = rfr.score(X_test, y_test)

print('Train Score:',rfr_score)
print('Test Score:', rfr_score_test)


plt.scatter(y_test,y_pred)
plt.xlabel('actual')
plt.ylabel('prediciton') 
plt.show()
# Out:
# Train Score: 0.9447191026747974
# Test Score: 0.5800501957453124

# %%
print("R2 Score: ", r2_score(y_test, rfr.predict(X_test)))
print("Mean Absolute Error: ", metrics.mean_absolute_error(y_test,y_pred))
print("Mean Squared Error: ", metrics.mean_squared_error(y_test,y_pred))
print("Root Mean Squared Error: ", np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score:  0.5800501957453124
# Mean Absolute Error:  1.3701907249275518
# Mean Squared Error:  4.098745014542459
# Root Mean Squared Error:  2.024535752843713

# %%
print("Root Mean Squared Error: ", np.sqrt(metrics.mean_squared_error(y_train,rfr.predict(X_train))))
# Out:
# Root Mean Squared Error:  0.6903888215994444

# %% [markdown]
# # Linear Regression

# %%
top.columns
# Out:
# Index(['Life Expectancy', 'Population', '% Rural', 'Premature Deaths',
#        '% Smoking', '% Obesity', '% Physical Inactivy', 'MHP Rate',
#        'Preventable Hospital Rate', '% Unemployed'],
#       dtype='object')

# %%
top.head()
# Out:
#    Life Expectancy  Population  % Rural  Premature Deaths  % Smoking  \
# 0        77.162581       55869    22921             787.0         20
# 1        78.213405      223234    77060            3147.0         19
# 2        74.054741       24686    18613             515.0         26
# 3        73.408784       22394    15663             476.0         23
# 4        74.370874       57826    51562            1100.0         23
#
#    % Obesity  % Physical Inactivy  MHP Rate  Preventable Hospital Rate  \
# 0         33                   31      29.0                     6650.0
# 1         30                   25      99.0                     3471.0
# 2         41                   28      12.0                     5314.0
# 3         37                   33      27.0                     6690.0
# 4         33                   33      17.0                     4440.0
#
#    % Unemployed
# 0           2.7
# 1           2.7
# 2           3.8
# 3           3.1
# 4           2.7

# %%
y = top['Life Expectancy']
X = top.drop(columns=['Life Expectancy'],axis=1)

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=123)

# %%
sscaler = StandardScaler()

X_train_scaled= sscaler.fit_transform(X_train)
X_test_scaled= sscaler.transform(X_test)

# %%
lr=LinearRegression()
lr_fit=lr.fit(X_train_scaled,y_train)
y_pred = lr_fit.predict(X_test_scaled)

# %%
plt.scatter(y_test,y_pred)

plt.title("Model predictions vs. actual values")
plt.xlabel("Actual")
plt.ylabel("Predictions")
# Out:
# Text(0, 0.5, 'Predictions')

# %%
#Evaluate the model.
lr_score = lr.score(X_train_scaled, y_train)
lr_score_test = lr.score(X_test_scaled, y_test)

print('Train Score:',lr_score)
print('Test Score:', lr_score_test)
# Out:
# Train Score: 0.5808775706468277
# Test Score: 0.5626152549436473

# %%
print("R2 Score: ", r2_score(y_test, lr.predict(X_test_scaled)))
print("Mean Absolute Error: ", metrics.mean_absolute_error(y_test,y_pred))
print("Mean Squared Error: ", metrics.mean_squared_error(y_test,y_pred))
print("Root Mean Squared Error: ", np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score:  0.5626152549436473
# Mean Absolute Error:  1.3999663878264559
# Mean Squared Error:  4.2689114867390465
# Root Mean Squared Error:  2.066134430945636

# %% [markdown]
# # KNN

# %%
y = top['Life Expectancy']
X = top.drop(columns=['Life Expectancy'],axis=1)

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=123)

# %%
sscaler = StandardScaler()

X_train_scaled= sscaler.fit_transform(X_train)
X_test_scaled= sscaler.transform(X_test)

# %%
test_scores = []
train_scores = []

for i in range(1,10):

    knn = KNeighborsRegressor(i)
    knn.fit(X_train_scaled,y_train)
    
    train_scores.append(knn.score(X_train_scaled,y_train))
    test_scores.append(knn.score(X_test_scaled,y_test))

# %%
print('Train Scores', train_scores)
print('Test Scores', test_scores)
# Out:
# Train Scores [1.0, 0.7943389843676245, 0.7254535461564966, 0.697350522890517, 0.6763977334734084, 0.6641184597675207, 0.6517359810680547, 0.6416325902912952, 0.634048911917177]
# Test Scores [0.2971162119804961, 0.42723035302408363, 0.503838176137728, 0.5137949789968731, 0.5498807529631574, 0.5539128012708936, 0.5604489627476761, 0.5636087832645007, 0.565448727226783]

# %%
print('Training Data Neighbors:', train_scores.index(max(train_scores))+1)
print('Testing Data Neighbors:', test_scores.index(max(test_scores))+1)
# Out:
# Training Data Neighbors: 1
# Testing Data Neighbors: 9

# %%
knnr=KNeighborsRegressor(n_neighbors = 9)
knnr.fit(X_train_scaled,y_train)
pred = knnr.predict (X_test_scaled)

# %%
print('Training Data Score: ', knnr.score(X_train_scaled, y_train))
print('Test Data Score: ', knnr.score(X_test_scaled,y_test))
# Out:
# Training Data Score:  0.634048911917177
# Test Data Score:  0.565448727226783

# %%
#Evaluate the model.
knnr_score = knnr.score(X_train_scaled, y_train)
knnr_score_test = knnr.score(X_test_scaled, y_test)

print('Train Score:',knnr_score)
print('Test Score:', knnr_score_test)


plt.scatter(y_test,y_pred)
plt.xlabel('actual')
plt.ylabel('prediction')
plt.show()
# Out:
# Train Score: 0.634048911917177
# Test Score: 0.565448727226783

# %%
print("Mean Absolute Error: ", metrics.mean_absolute_error(y_test,y_pred))
print("Mean Squared Error: ", metrics.mean_squared_error(y_test,y_pred))
print("Root Mean Squared Error: ", np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score: ", r2_score(y, knnr.predict(X)))
# Out:
# Mean Absolute Error:  1.3999663878264559
# Mean Squared Error:  4.2689114867390465
# Root Mean Squared Error:  2.066134430945636
# R2 Score:  -1.3164139694232726
